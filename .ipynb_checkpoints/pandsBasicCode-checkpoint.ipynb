# %%
import pandas as pd 
import numpy as np 
import missingno as msno

# %%
pwd
# Out:
# 'E:\\CODE\\Python ML\\02-pandas\\basic\\pandasBasic'

# %%
path = r'E:\Courses\Machine Learning & Data Science Diploma  Arabic\Code-for-my-Courses-Mohammed-Agoor-main\Code-for-my-Courses-Mohammed-Agoor-main\01- Data Analysis\02- Numpy & pandas\Files\homelessness.csv'

# %%
df_homlessness = pd.read_csv(path)   # data frame

# %%
df_homlessness.info()
# بيعرض تفاصيل عن الداتا فريم زي أنواع البيانات وعدد القيم الفاضية.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   region          51 non-null     object
#  1   state           51 non-null     object
#  2   individuals     51 non-null     int64
#  3   family_members  51 non-null     int64
#  4   state_pop       51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
df_homlessness.describe()
#بيجيب إحصائيات عن البيانات الرقمية زي المتوسط والحدود الدنيا والقصوى.
# Out:
#          individuals  family_members     state_pop
# count      51.000000       51.000000  5.100000e+01
# mean     7225.784314     3504.882353  6.405637e+06
# std     15991.025083     7805.411811  7.327258e+06
# min       434.000000       75.000000  5.776010e+05
# 25%      1446.500000      592.000000  1.777414e+06
# 50%      3082.000000     1482.000000  4.461153e+06
# 75%      6781.500000     3196.000000  7.340946e+06
# max    109008.000000    52070.000000  3.946159e+07

# %%
df_homlessness.isna().any()
# Out:
# region            False
# state             False
# individuals       False
# family_members    False
# state_pop         False
# dtype: bool

# %%
df_homlessness['individuals']
# Out:
# 0       2570
# 1       1434
# 2       7259
# 3       2280
# 4     109008
# 5       7607
# 6       2280
# 7        708
# 8       3770
# 9      21443
# 10      6943
# 11      4131
# 12      1297
# 13      6752
# 14      3776
# 15      1711
# 16      1443
# 17      2735
# 18      2540
# 19      1450
# 20      4914
# 21      6811
# 22      5209
# 23      3993
# 24      1024
# 25      3776
# 26       983
# 27      1745
# 28      7058
# 29       835
# 30      6048
# 31      1949
# 32     39827
# 33      6451
# 34       467
# 35      6929
# 36      2823
# 37     11139
# 38      8163
# 39       747
# 40      3082
# 41       836
# 42      6139
# 43     19199
# 44      1904
# 45       780
# 46      3928
# 47     16424
# 48      1021
# 49      2740
# 50       434
# Name: individuals, dtype: int64

# %%
df_homlessness.head()
# Out:
#                region       state  individuals  family_members  state_pop
# 0  East South Central     Alabama         2570             864    4887681
# 1             Pacific      Alaska         1434             582     735139
# 2            Mountain     Arizona         7259            2606    7158024
# 3  West South Central    Arkansas         2280             432    3009733
# 4             Pacific  California       109008           20964   39461588

# %%
df_homlessness[['state','region']]
# Out:
#                    state              region
# 0                Alabama  East South Central
# 1                 Alaska             Pacific
# 2                Arizona            Mountain
# 3               Arkansas  West South Central
# 4             California             Pacific
# 5               Colorado            Mountain
# 6            Connecticut         New England
# 7               Delaware      South Atlantic
# 8   District of Columbia      South Atlantic
# 9                Florida      South Atlantic
# 10               Georgia      South Atlantic
# 11                Hawaii             Pacific
# 12                 Idaho            Mountain
# 13              Illinois  East North Central
# 14               Indiana  East North Central
# 15                  Iowa  West North Central
# 16                Kansas  West North Central
# 17              Kentucky  East South Central
# 18             Louisiana  West South Central
# 19                 Maine         New England
# ...

# %%
df_homlessness.sort_values(by = 'state' , )
#بيرتب الداتا حسب عمود state تصاعديًا بشكل افتراضي.
# Out:
#                 region                 state  individuals  family_members  \
# 0   East South Central               Alabama         2570             864
# 1              Pacific                Alaska         1434             582
# 2             Mountain               Arizona         7259            2606
# 3   West South Central              Arkansas         2280             432
# 4              Pacific            California       109008           20964
# 5             Mountain              Colorado         7607            3250
# 6          New England           Connecticut         2280            1696
# 7       South Atlantic              Delaware          708             374
# 8       South Atlantic  District of Columbia         3770            3134
# 9       South Atlantic               Florida        21443            9587
# 10      South Atlantic               Georgia         6943            2556
# 11             Pacific                Hawaii         4131            2399
# ...

# %%
df_homlessness.sort_values(by = 'state' , ascending=False )
#بيرتب الداتا تنازليًا حسب عمود state.
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming          434             205
# 49  East North Central             Wisconsin         2740            2167
# 48      South Atlantic         West Virginia         1021             222
# 47             Pacific            Washington        16424            5880
# 46      South Atlantic              Virginia         3928            2047
# 45         New England               Vermont          780             511
# 44            Mountain                  Utah         1904             972
# 43  West South Central                 Texas        19199            6111
# 42  East South Central             Tennessee         6139            1744
# 41  West North Central          South Dakota          836             323
# 40      South Atlantic        South Carolina         3082             851
# 39         New England          Rhode Island          747             354
# ...

# %%
#df_homlessness.sort_values(by = 'state' , ascending=False , inplace = True  )
#بيرتب الداتا تنازليًا حسب عمود state ويعدلها في نفس الداتا فريم مباشرة.

# %%
df_homlessness.sort_values(by = ['individuals','state_pop'])
# بيرتب الداتا تصاعديًا حسب individuals، ولو القيم متساوية، يرتبها حسب state_pop
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming          434             205
# 34  West North Central          North Dakota          467              75
# 7       South Atlantic              Delaware          708             374
# 39         New England          Rhode Island          747             354
# 45         New England               Vermont          780             511
# 29         New England         New Hampshire          835             615
# 41  West North Central          South Dakota          836             323
# 26            Mountain               Montana          983             422
# 48      South Atlantic         West Virginia         1021             222
# 24  East South Central           Mississippi         1024             328
# 12            Mountain                 Idaho         1297             715
# 1              Pacific                Alaska         1434             582
# ...

# %%
df_homlessness.sort_values(by = ['individuals','state_pop'] , ascending=[True , False ])
# بيرتب الداتا تصاعديًا حسب individuals، ولو القيم متساوية، يرتبها تنازليًا حسب state_pop.
# Out:
#                 region                 state  individuals  family_members  \
# 50            Mountain               Wyoming          434             205
# 34  West North Central          North Dakota          467              75
# 7       South Atlantic              Delaware          708             374
# 39         New England          Rhode Island          747             354
# 45         New England               Vermont          780             511
# 29         New England         New Hampshire          835             615
# 41  West North Central          South Dakota          836             323
# 26            Mountain               Montana          983             422
# 48      South Atlantic         West Virginia         1021             222
# 24  East South Central           Mississippi         1024             328
# 12            Mountain                 Idaho         1297             715
# 1              Pacific                Alaska         1434             582
# ...

# %%
df_homlessness['state'].unique()
#بيرجع قائمة بكل أسماء الولايات بدون تكرار.
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df_homlessness['state'].value_counts()
# بيحسب عدد التكرارات لكل ولاية ويرتبهم تنازليًا.
# Out:
# Alabama                 1
# Pennsylvania            1
# Nevada                  1
# New Hampshire           1
# New Jersey              1
# New Mexico              1
# New York                1
# North Carolina          1
# North Dakota            1
# Ohio                    1
# Oklahoma                1
# Oregon                  1
# Rhode Island            1
# Montana                 1
# South Carolina          1
# South Dakota            1
# Tennessee               1
# Texas                   1
# Utah                    1
# Vermont                 1
# Virginia                1
# Washington              1
# West Virginia           1
# Wisconsin               1
# Nebraska                1
# Missouri                1
# Alaska                  1
# Idaho                   1
# Arizona                 1
# Arkansas                1
# California              1
# Colorado                1
# Connecticut             1
# Delaware                1
# District of Columbia    1
# ...

# %%
df_homlessness[df_homlessness['region'] == 'Mountain']
# بيرجع الصفوف اللي فيها region = 'Mountain' بس
# Out:
#       region       state  individuals  family_members  state_pop
# 2   Mountain     Arizona         7259            2606    7158024
# 5   Mountain    Colorado         7607            3250    5691287
# 12  Mountain       Idaho         1297             715    1750536
# 26  Mountain     Montana          983             422    1060665
# 28  Mountain      Nevada         7058             486    3027341
# 31  Mountain  New Mexico         1949             602    2092741
# 44  Mountain        Utah         1904             972    3153550
# 50  Mountain     Wyoming          434             205     577601

# %%
df_homlessness[(df_homlessness['region'] =='Mountain') | (df_homlessness['family_members'] <300 )]
#يرجع الصفوف اللي فيها region = 'Mountain' أو family_members أقل من 300.
# Out:
#                 region          state  individuals  family_members  state_pop
# 2             Mountain        Arizona         7259            2606    7158024
# 5             Mountain       Colorado         7607            3250    5691287
# 12            Mountain          Idaho         1297             715    1750536
# 26            Mountain        Montana          983             422    1060665
# 28            Mountain         Nevada         7058             486    3027341
# 31            Mountain     New Mexico         1949             602    2092741
# 34  West North Central   North Dakota          467              75     758080
# 44            Mountain           Utah         1904             972    3153550
# 48      South Atlantic  West Virginia         1021             222    1804291
# 50            Mountain        Wyoming          434             205     577601

# %%
df_homlessness[df_homlessness['region'] =='Mountain']['state_pop'].mean()
# بيحسب متوسط عدد السكان للولايات اللي في منطقة Mountain بس
# Out:
# 3063968.125

# %%
df_homlessness.groupby('region')['state_pop'].mean()
# بيحسب متوسط عدد السكان في كل منطقة (region).
# Out:
# region
# East North Central    9.377277e+06
# East South Central    4.775371e+06
# Mid-Atlantic          1.373910e+07
# Mountain              3.063968e+06
# New England           2.471554e+06
# Pacific               1.066462e+07
# South Atlantic        7.247736e+06
# West North Central    3.050034e+06
# West South Central    1.005958e+07
# Name: state_pop, dtype: float64

# %%
df_homlessness.groupby('region')['state_pop'].agg(['mean', 'min', 'max'])
# بيحسب المتوسط، الحد الأدنى، والحد الأقصى لعدد السكان في كل منطقة (region).
# Out:
#                             mean      min       max
# region
# East North Central  9.377277e+06  5807406  12723071
# East South Central  4.775371e+06  2981020   6771631
# Mid-Atlantic        1.373910e+07  8886025  19530351
# Mountain            3.063968e+06   577601   7158024
# New England         2.471554e+06   624358   6882635
# Pacific             1.066462e+07   735139  39461588
# South Atlantic      7.247736e+06   701547  21244317
# West North Central  3.050034e+06   758080   6121623
# West South Central  1.005958e+07  3009733  28628666

# %%
df_homlessness.groupby(['region' , 'state'])['state_pop'].agg({'min','max'})
#df_homlessness.groupby(['region', 'state'])['state_pop'].agg(['min', 'max'])
# بيحسب أقل وأكبر عدد سكان لكل ولاية داخل كل منطقة (region).
# Out:
#                                               min       max
# region             state
# East North Central Illinois              12723071  12723071
#                    Indiana                6695497   6695497
#                    Michigan               9984072   9984072
#                    Ohio                  11676341  11676341
#                    Wisconsin              5807406   5807406
# East South Central Alabama                4887681   4887681
#                    Kentucky               4461153   4461153
#                    Mississippi            2981020   2981020
#                    Tennessee              6771631   6771631
# Mid-Atlantic       New Jersey             8886025   8886025
#                    New York              19530351  19530351
#                    Pennsylvania          12800922  12800922
# Mountain           Arizona                7158024   7158024
#                    Colorado               5691287   5691287
# ...
